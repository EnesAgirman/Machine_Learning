# %% [markdown]
# <a href="https://colab.research.google.com/github/EnesAgirman/Machine_Learning/blob/main/Codes/Classification_and_Logistic_Regression/Binary_Classification_Perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import math
from IPython.display import clear_output
from numpy.ma.core import squeeze
import time

# %%
# For the dataset: https://www.kaggle.com/datasets/gabrielsantello/advertisement-click-on-ad
df = pd.read_csv('advertising.csv')
df.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male  \
# 0                     68.95   35     61833.90                256.09     0
# 1                     80.23   31     68441.85                193.77     1
# 2                     69.47   26     59785.94                236.50     0
# 3                     74.15   29     54806.18                245.89     1
# 4                     68.37   35     73889.99                225.58     0
#
#    Clicked on Ad
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
df.describe()
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# ...

# %%
def g(z):
  if z >= 0:
    return 1
  else:
    return 0

def h(aTheta, aX):
  return g(np.dot(aTheta, aX))

def updateTheta(aLabel, j, aTheta, aX, aY, aAlpha):
  for col in aX:
    aTheta[j] = aTheta[j] + aAlpha * ( aY[aLabel] - h(aTheta, aX[j]) ) * col[j]

def printAccuracy():
  count = 0
  totalCount = 0
  for index, row in df.iterrows():
    totalCount += 1
    if h(theta, row) == row["Clicked on Ad"]:
      count += 1
  print("accuracy: " + str( count / totalCount ))



theta = np.ones( df.shape[1] )

Y = df["Clicked on Ad"]

X = df[[ "Daily Time Spent on Site", "Age",	"Area Income",	"Daily Internet Usage",	"Male" ]]

alpha = 0.0000001

count = 0
totalCount = 0
printCount = 0

# %%
for i in range(100):
  for index, row in df.iterrows():
    colCount = 0
    for col in row:
      theta[colCount] = theta[colCount] + alpha * ( row["Clicked on Ad"] - h( theta, row ) ) * col
      colCount += 1
    if h(theta, row) == row["Clicked on Ad"]:
      count += 1
    totalCount += 1
  if printCount % 10 == 0:
    print("accuracy: % " + str(100 * count / totalCount) )

  count = 0
  totalCount = 0
  printCount += 1
# Out:
# accuracy: % 78.7
# accuracy: % 90.9
# accuracy: % 91.7
# accuracy: % 91.9
# accuracy: % 92.4
# accuracy: % 92.0
# accuracy: % 92.4
# accuracy: % 92.4
# accuracy: % 92.4
# accuracy: % 91.8
