# %% [markdown]
# <a href="https://colab.research.google.com/github/EnesAgirman/Machine_Learning/blob/main/Codes/Classification_and_Logistic_Regression/Binary_Classification_Perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import math
from IPython.display import clear_output
from numpy.ma.core import squeeze
import time

# %%
# For the dataset: https://www.kaggle.com/datasets/gabrielsantello/advertisement-click-on-ad
df_all = pd.read_csv('advertising.csv')
df_all.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male  \
# 0                     68.95   35     61833.90                256.09     0
# 1                     80.23   31     68441.85                193.77     1
# 2                     69.47   26     59785.94                236.50     0
# 3                     74.15   29     54806.18                245.89     1
# 4                     68.37   35     73889.99                225.58     0
#
#    Intersect  Clicked on Ad
# 0          1              0
# 1          1              0
# 2          1              0
# 3          1              0
# 4          1              0

# %%
df_all.describe()
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Male                      1000 non-null   int64
#  5   Intersect                 1000 non-null   int64
#  6   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(4)
# memory usage: 54.8 KB

# %%
# df_all = df_all[[ "Daily Time Spent on Site", "Age",	"Area Income",	"Daily Internet Usage",	"Male", "Intersect" ]]
df = df_all.iloc[:800,:]
df_test = df_all.iloc[800:,:]
df_test = df_test[:200]
df.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male  \
# 0                     68.95   35     61833.90                256.09     0
# 1                     80.23   31     68441.85                193.77     1
# 2                     69.47   26     59785.94                236.50     0
# 3                     74.15   29     54806.18                245.89     1
# 4                     68.37   35     73889.99                225.58     0
#
#    Intersect  Clicked on Ad
# 0          1              0
# 1          1              0
# 2          1              0
# 3          1              0
# 4          1              0

# %%
def g(z):
  if z >= 0:
    return 1
  else:
    return 0

def h(aTheta, aX):
  return g(np.dot(aTheta, aX))

def updateTheta(aLabel, j, aTheta, aX, aY, aAlpha):
  for col in aX:
    aTheta[j] = aTheta[j] + aAlpha * ( aY[aLabel] - h(aTheta, aX[j]) ) * col[j]

def printAccuracy(aPrintCount):
  count = 0
  totalCount = 0
  aPrintCount += 1
  for index, row in df_test.iterrows():
    for col in row:
      if h(theta, row[:-1]) == row["Clicked on Ad"]:
        count += 1
        # print(theta.shape, row[:-1].shape)
        # print(str( h(theta, row[:-1]) ) + " == " + str(row["Clicked on Ad"]))
      else:
        # print(str( h(theta, row[:-1]) ) + " !! " + str(row["Clicked on Ad"]))
        pass
      totalCount += 1
  if aPrintCount % 1 == 0:
    print("accuracy: % " + str(100 * count / totalCount) )


X = df[[ "Daily Time Spent on Site", "Age",	"Area Income",	"Daily Internet Usage",	"Male", "Intersect" ]]
theta = np.ones( X.shape[1] )
theta[-1] = -100000

alpha = 0.01

count = 0
totalCount = 0
printCount = 0

# %%
for i in range(20):
  printAccuracy(printCount)
  printCount += 1
  for index, row in df.iterrows():
    colCount = 0
    for col in row:
      theta[colCount-1] = theta[colCount-1] + alpha * ( row["Clicked on Ad"] - h( theta, row[:-1] ) ) * col
      colCount += 1
  # print(theta[1:4])
  # print(h(theta, row))
# Out:
# accuracy: % 44.0
# accuracy: % 70.5
# accuracy: % 77.0
# accuracy: % 79.5
# accuracy: % 81.0
# accuracy: % 81.0
# accuracy: % 80.5
# accuracy: % 81.0
# accuracy: % 79.5
# accuracy: % 78.0
# accuracy: % 80.0
# accuracy: % 80.5
# accuracy: % 80.5
# accuracy: % 81.0
# accuracy: % 81.0
# accuracy: % 81.5
# accuracy: % 81.5
# accuracy: % 82.0
# accuracy: % 82.5
# accuracy: % 82.5
